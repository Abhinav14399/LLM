# %%
# Import the BERT tokenizer from the Transformers library
from transformers import BertTokenizer
# Load a pre-trained BERT tokenizer (lowercase English model)
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
# Input text that we want to tokenize (LLM topic)
text = """Large language models like GPT, BERT, and LLAMA are used in chatbots and AI
research."""
# Tokenize the text into smaller pieces called subword tokens
tokens = tokenizer.tokenize(text)
# Print the subword tokens generated by BERT
print("Subword Tokens:", tokens)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Subword Tokens: ['large', 'language', 'models', 'like', 'gp', '##t', ',', 'bert', ',', 'and', 'll', '##ama', 'are', 'used', 'in', 'chat', '##bots', 'and', 'ai', 'research', '.']
